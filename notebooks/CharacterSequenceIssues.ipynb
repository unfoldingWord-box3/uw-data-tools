# %% [markdown]
# This notebook studies the variation in the ordering of the diacritics in UHB
#
# Author: J de Joode
#
# - Date: June 16, 2021
# - Updated: Nov 30, 2021

# %%
import glob
from collections import Counter
import unicodedata
import pandas as pd
import re

# %% [markdown]
# This notebook assumes that you have a data directory setup one level up.

# %%
files = glob.glob('../data/hbo_uhb/*.usfm')
contents = []
for f in files:
    with open(f) as ipf:
        contents.append(ipf.read())

# %%
len(contents)
# Out:
# 39

# %% [markdown]
# Read all the contents

# %%
ot = '\n\n'.join(contents)

# %%
ot_clean = ' '.join(ot.split()) # make whitespace consistent
lemmata = re.findall(r'\|lemma=".*?"', ot_clean)  # extract the lemmata
ot_no_lemmas = re.sub(r'\|lemma=".*?"', ' ', ot_clean)  # remove the lemmata

# %% [markdown]
# Count the individual characters, this also includes characters that are part of the USFM markup

# %%
counter = Counter(ot_no_lemmas).most_common()
counter
# Out:
# [(' ', 1594684),
#  ('"', 1314480),
#  ('w', 721749),
#  ('r', 714614),
#  ('o', 663254),
#  ('=', 657240),
#  ('\\', 645779),
#  ('H', 602627),
#  ('s', 508488),
#  ('m', 496752),
#  ('t', 490341),
#  ('p', 487672),
#  ('e', 405596),
#  ('c', 356648),
#  ('*', 353967),
#  ('x', 353635),
#  ('h', 352865),
#  ('-', 350977),
#  ('n', 337408),
#  (':', 325226),
#  ('g', 314892),
#  ('/', 309852),
#  (',', 306488),
#  ('3', 218887),
#  ('ּ', 170579),
#  ('0', 169603),
#  ('1', 168347),
#  ('a', 168270),
#  ('\u2060', 163919),
#  ('ָ', 151785),
#  ('N', 150550),
#  ('ְ', 150189),
#  ('י', 138624),
#  ('b', 137297),
#  ('2', 134176),
#  ('5', 131928),
#  ('ו', 130383),
#  ('8', 124999),
#  ('i', 120458),
#  ('d', 117358),
#  ('ַ', 117124),
#  ('4', 113204),
#  ('ִ', 108848),
#  ('6', 103838),
#  ('ה', 102232),
#  ('7', 99510),
#  ('א', 95957),
#  ('9', 88586),
#  ('ל', 88565),
#  ('l', 76021),
#  ('ֶ', 75199),
#  ('V', 74009),
#  ('ֹ', 73403),
#  ('ר', 68297),
#  ('ב', 65458),
#  ('R', 64492),
#  ('ת', 63481),
#  ('ֵ', 58969),
#  ('ש', 58387),
#  ('מ', 57844),
#  ('C', 57668),
#  ('q', 56862),
#  ('T', 54582),
#  ('S', 47768),
#  ('ׁ', 46010),
#  ('f', 45774),
#  ('ע', 44970),
#  ('־', 42579),
#  ('ם', 41417),
#  ('֣', 41281),
#  ('ֽ', 41262),
#  ('נ', 40036),
#  ('֖', 37072),
#  ('v', 35129),
#  ('כ', 33558),
#  ('֥', 33162),
#  ('ד', 32505),
#  ('ח', 27720),
#  ('ֲ', 25579),
#  ('֔', 25524),
#  ('k', 23983),
#  ('׃', 23193),
#  ('֑', 21541),
#  ('֙', 20585),
#  ('A', 19278),
#  ('פ', 16966),
#  ('ק', 16317),
#  ('ן', 15274),
#  ('ך', 14049),
#  ('֗', 12789),
#  ('֤', 12586),
#  ('ׂ', 12069),
#  ('צ', 11759),
#  ('֨', 11321),
#  ('ג', 10127),
#  ('ס', 9655),
#  ('ז', 9117),
#  ('P', 8208),
#  ('֛', 7850),
#  ('ט', 6344),
#  ('u', 5897),
#  ('y', 5515),
#  ('ֱ', 4468),
#  ('ֻ', 4356),
#  ('D', 4319),
#  ('֜', 4156),
#  ('j', 3874),
#  ('ץ', 3290),
#  ('֧', 3272),
#  ('֝', 2966),
#  ('+', 2893),
#  ('֭', 2689),
#  ('ף', 2560),
#  ('׀', 2273),
#  ('֩', 1860),
#  ('֞', 1728),
#  ('֕', 1655),
#  ('֮', 1222),
#  ('֠', 1199),
#  ('֚', 1176),
#  ('֒', 952),
#  ('֡', 949),
#  ('K', 636),
#  ('ֳ', 632),
#  ('z', 628),
#  ('Q', 423),
#  ('ֺ', 412),
#  ('֫', 407),
#  ('֪', 252),
#  ('֘', 212),
#  ('֬', 185),
#  ('|', 93),
#  ('B', 82),
#  ('M', 57),
#  ('ׄ', 53),
#  ('F', 49),
#  ('֓', 46),
#  ('U', 42),
#  ('.', 41),
#  ('W', 39),
#  ('®', 39),
#  ('E', 38),
#  ('J', 36),
#  ('O', 35),
#  ('֟', 16),
#  ('L', 16),
#  ('Z', 14),
#  ('֦', 14),
#  ('G', 9),
#  ('I', 9),
#  ('׆', 9),
#  ('ֿ', 5),
#  ('(', 5),
#  (')', 5),
#  ('ׅ', 3),
#  ('X', 1),
#  ('[', 1),
#  (']', 1),
#  ('שׁ', 1)]

# %% [markdown]
# # Extract unicode metadata

# %% [markdown]
# We'll be using the unicodedata module to gain more insight into the actual form/shape of the characters

# %%
information = 'char frequency name category bidirectional decomposition mirrored'.split()

output = []
for char in counter:
    c = char[0]
    freq = char[1]
    tmp = [c, 
           freq, 
           unicodedata.name(c), 
           unicodedata.category(c), 
           unicodedata.bidirectional(c), 
           unicodedata.decomposition(c),
           unicodedata.mirrored(c),
          ]
    output.append(tmp)

# %% [markdown]
# We can now convert them to a dataframe

# %%
df = pd.DataFrame(output, columns=information)

# %% [markdown]
# This dataframe now as the character, its frequency, its name, category, whether it is bidir, its decomposition where possible, and whether it has a mirror equivalent

# %%
df
# Out:
#     char  frequency                              name category bidirectional  \
# 0           1594684                             SPACE       Zs            WS
# 1      "    1314480                    QUOTATION MARK       Po            ON
# 2      w     721749              LATIN SMALL LETTER W       Ll             L
# 3      r     714614              LATIN SMALL LETTER R       Ll             L
# 4      o     663254              LATIN SMALL LETTER O       Ll             L
# ..   ...        ...                               ...      ...           ...
# 154    ׅ          3             HEBREW MARK LOWER DOT       Mn           NSM
# 155    X          1            LATIN CAPITAL LETTER X       Lu             L
# 156    [          1               LEFT SQUARE BRACKET       Ps            ON
# 157    ]          1              RIGHT SQUARE BRACKET       Pe            ON
# 158    שׁ          1  HEBREW LETTER SHIN WITH SHIN DOT       Lo             R
#
#     decomposition  mirrored
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ..            ...       ...
# 154                       0
# 155                       0
# 156                       1
# 157                       1
# 158     05E9 05C1         0
#
# [159 rows x 7 columns]

# %% [markdown]
# NB: note that the dataframe above shows that there is a case where the shin and shin dot are combined into a single character.
#
# **This needs a fix**
#
# To find other possible cases that can be decomposed, we run the following query

# %%
df.loc[-(df.decomposition == '')]
# Out:
#     char  frequency                              name category bidirectional  \
# 158    שׁ          1  HEBREW LETTER SHIN WITH SHIN DOT       Lo             R
#
#     decomposition  mirrored
# 158     05E9 05C1         0

# %% [markdown]
# We can now extract all the Hebrew characters by filtering on the bidirectional column

# %%
hebrew = df.loc[df.bidirectional.isin(('NSM', 'R'))].char.tolist()
hebrew
# Out:
# ['ּ',
#  'ָ',
#  'ְ',
#  'י',
#  'ו',
#  'ַ',
#  'ִ',
#  'ה',
#  'א',
#  'ל',
#  'ֶ',
#  'ֹ',
#  'ר',
#  'ב',
#  'ת',
#  'ֵ',
#  'ש',
#  'מ',
#  'ׁ',
#  'ע',
#  '־',
#  'ם',
#  '֣',
#  'ֽ',
#  'נ',
#  '֖',
#  'כ',
#  '֥',
#  'ד',
#  'ח',
#  'ֲ',
#  '֔',
#  '׃',
#  '֑',
#  '֙',
#  'פ',
#  'ק',
#  'ן',
#  'ך',
#  '֗',
#  '֤',
#  'ׂ',
#  'צ',
#  '֨',
#  'ג',
#  'ס',
#  'ז',
#  '֛',
#  'ט',
#  'ֱ',
#  'ֻ',
#  '֜',
#  'ץ',
#  '֧',
#  '֝',
#  '֭',
#  'ף',
#  '׀',
#  '֩',
#  '֞',
#  '֕',
#  '֮',
#  '֠',
#  '֚',
#  '֒',
#  '֡',
#  'ֳ',
#  'ֺ',
#  '֫',
#  '֪',
#  '֘',
#  '֬',
#  'ׄ',
#  '֓',
#  '֟',
#  '֦',
#  '׆',
#  'ֿ',
#  'ׅ',
#  'שׁ']

# %% [markdown]
# This also makes it possible to get rid of all the markup and only keep the Hebrew.
# We'll disregard the weird spacing as that's not the focus of our analysis

# %%
tokens = ot_no_lemmas.split()
tokens_hb = []
for token in tokens:
    tmp = ''.join(char for char in token if char in hebrew)
    tokens_hb.append(tmp)
hb = ' '.join(tokens_hb)

# %%
print(hb[:100])
# Out:
#                             וּבִשְׁנַ֣ת    אַחַ֗ת    לְכ֨וֹרֶשׁ֙     מֶ֣לֶךְ     פָּרַ֔ס     לִכְל֥ו

# %%
hb = ' '.join(hb.split())
hb[:100]
# Out:
# 'וּבִשְׁנַ֣ת אַחַ֗ת לְכ֨וֹרֶשׁ֙ מֶ֣לֶךְ פָּרַ֔ס לִכְל֥וֹת דְּבַר ־ יְהוָ֖ה מִפִּ֣י יִרְמְיָ֑ה הֵעִ֣יר'

# %% [markdown]
# # Extract the different categories: punctuation, vowels, accents, etc.

# %% [markdown]
# Now we can start to focus on the different categories

# %%
df.loc[df.char.isin(hebrew)].category.value_counts()
# Out:
# Mn    48
# Lo    28
# Po     3
# Pd     1
# Name: category, dtype: int64

# %% [markdown]
# Vowels and accents are part of the same category

# %%
df.loc[df.char.isin(hebrew) & (df.category=="Mn")]
# Out:
#     char  frequency                              name category bidirectional  \
# 24     ּ     170579      HEBREW POINT DAGESH OR MAPIQ       Mn           NSM
# 29     ָ     151785               HEBREW POINT QAMATS       Mn           NSM
# 87                        0
# 88                        0
# 92                        0
# 94                        0
# 95                        0
# 96                        0
# 99                        0
# 107                       0
# 112                       0
# 158     05E9 05C1         0

# %%
df.loc[df.char.isin(hebrew) & (df.category=="Po")]
# Out:
#     char  frequency                            name category bidirectional  \
# 81     ׃      23193    HEBREW PUNCTUATION SOF PASUQ       Po             R
# 113    ׀       2273        HEBREW PUNCTUATION PASEQ       Po             R
# 150    ׆          9  HEBREW PUNCTUATION NUN HAFUKHA       Po             R
#
#     decomposition  mirrored
# 81                        0
# 113                       0
# 150                       0

# %%
df.loc[df.char.isin(hebrew) & (df.category=="Pd")]
# Out:
#    char  frequency                      name category bidirectional  \
# 67    ־      42579  HEBREW PUNCTUATION MAQAF       Pd             R
#
#    decomposition  mirrored
# 67                       0

# %% [markdown]
# Let's create three columns to capture the metadata: point, accent, and vowel

# %%
df['point'] = False
df.loc[df.char.isin(hebrew) & (df.category=="Mn") & (df.name.str.contains(r'POINT')), 'point'] = True

# %%
df['accent'] = False
df.loc[df.char.isin(hebrew) & (df.category=="Mn") & (df.name.str.contains(r'ACCENT')), 'accent'] = True

# %%
vowels = ['HEBREW POINT QAMATS',
     'HEBREW POINT SHEVA',
     'HEBREW POINT PATAH',
     'HEBREW POINT HIRIQ',
     'HEBREW POINT SEGOL',
     'HEBREW POINT HOLAM',
     'HEBREW POINT TSERE',
     'HEBREW POINT HATAF PATAH',
     'HEBREW POINT HATAF SEGOL',
     'HEBREW POINT QUBUTS',
     'HEBREW POINT HATAF QAMATS',
     'HEBREW POINT HOLAM HASER FOR VAV',]

# %%
df['vowel'] = False
df.loc[(df.point) & (df.name.isin(vowels)), 'vowel'] = True

# %% [markdown]
# This allows us to create specific queries

# %%
df.loc[(-df.vowel) & (df.point)]  # - vowel, + point
# Out:
#     char  frequency                          name category bidirectional  \
# 27     ּ     170575  HEBREW POINT DAGESH OR MAPIQ       Mn           NSM
# 65     ׁ      46010         HEBREW POINT SHIN DOT       Mn           NSM
# 71     ֽ      41262            HEBREW POINT METEG       Mn           NSM
# 91     ׂ      12069          HEBREW POINT SIN DOT       Mn           NSM
# 151    ֿ          5             HEBREW POINT RAFE       Mn           NSM
#
#     decomposition  mirrored  point  accent  vowel
# 27                        0   True   False  False
# 65                        0   True   False  False
# 71                        0   True   False  False
# 91                        0   True   False  False
# 151                       0   True   False  False

# %% [markdown]
# We'll save them in separate lists for easy retrieval later

# %%
V = df.loc[(df.vowel)].name.tolist()
V
# Out:
# ['HEBREW POINT QAMATS',
#  'HEBREW POINT SHEVA',
#  'HEBREW POINT PATAH',
#  'HEBREW POINT HIRIQ',
#  'HEBREW POINT SEGOL',
#  'HEBREW POINT HOLAM',
#  'HEBREW POINT TSERE',
#  'HEBREW POINT HATAF PATAH',
#  'HEBREW POINT HATAF SEGOL',
#  'HEBREW POINT QUBUTS',
#  'HEBREW POINT HATAF QAMATS',
#  'HEBREW POINT HOLAM HASER FOR VAV']

# %%
P = df.loc[(df.point) & (-df.vowel)].name.tolist()
P
# Out:
# ['HEBREW POINT DAGESH OR MAPIQ',
#  'HEBREW POINT SHIN DOT',
#  'HEBREW POINT METEG',
#  'HEBREW POINT SIN DOT',
#  'HEBREW POINT RAFE']

# %%
A = df.loc[df.accent].name.tolist()
A
# Out:
# ['HEBREW ACCENT MUNAH',
#  'HEBREW ACCENT TIPEHA',
#  'HEBREW ACCENT MERKHA',
#  'HEBREW ACCENT ZAQEF QATAN',
#  'HEBREW ACCENT ETNAHTA',
#  'HEBREW ACCENT PASHTA',
#  'HEBREW ACCENT REVIA',
#  'HEBREW ACCENT MAHAPAKH',
#  'HEBREW ACCENT QADMA',
#  'HEBREW ACCENT TEVIR',
#  'HEBREW ACCENT GERESH',
#  'HEBREW ACCENT DARGA',
#  'HEBREW ACCENT GERESH MUQDAM',
#  'HEBREW ACCENT DEHI',
#  'HEBREW ACCENT TELISHA QETANA',
#  'HEBREW ACCENT GERSHAYIM',
#  'HEBREW ACCENT ZAQEF GADOL',
#  'HEBREW ACCENT ZINOR',
#  'HEBREW ACCENT TELISHA GEDOLA',
#  'HEBREW ACCENT YETIV',
#  'HEBREW ACCENT SEGOL',
#  'HEBREW ACCENT PAZER',
#  'HEBREW ACCENT OLE',
#  'HEBREW ACCENT YERAH BEN YOMO',
#  'HEBREW ACCENT ZARQA',
#  'HEBREW ACCENT ILUY',
#  'HEBREW ACCENT SHALSHELET',
#  'HEBREW ACCENT QARNEY PARA',
#  'HEBREW ACCENT MERKHA KEFULA']

# %%
C = df.loc[df.char.isin(hebrew) & (df.category=="Lo")].name.tolist()
C
# Out:
# ['HEBREW LETTER YOD',
#  'HEBREW LETTER VAV',
#  'HEBREW LETTER HE',
#  'HEBREW LETTER ALEF',
#  'HEBREW LETTER LAMED',
#  'HEBREW LETTER RESH',
#  'HEBREW LETTER BET',
#  'HEBREW LETTER TAV',
#  'HEBREW LETTER SHIN',
#  'HEBREW LETTER MEM',
#  'HEBREW LETTER AYIN',
#  'HEBREW LETTER FINAL MEM',
#  'HEBREW LETTER NUN',
#  'HEBREW LETTER KAF',
#  'HEBREW LETTER DALET',
#  'HEBREW LETTER HET',
#  'HEBREW LETTER PE',
#  'HEBREW LETTER QOF',
#  'HEBREW LETTER FINAL NUN',
#  'HEBREW LETTER FINAL KAF',
#  'HEBREW LETTER TSADI',
#  'HEBREW LETTER GIMEL',
#  'HEBREW LETTER SAMEKH',
#  'HEBREW LETTER ZAYIN',
#  'HEBREW LETTER TET',
#  'HEBREW LETTER FINAL TSADI',
#  'HEBREW LETTER FINAL PE',
#  'HEBREW LETTER SHIN WITH SHIN DOT']

# %% [markdown]
# # Transform the HB into a CVAPX chain
#
# Let's transform our dear Hebrew Bible (almost sounds like the start of a letter) into a sequence

# %%
output = []
for char in hb:
    name = unicodedata.name(char)
    if name in V:
        output.append('V')
    elif name in A:
        output.append('A')
    elif name in C:
        output.append('C')
    elif name in P:
        output.append('P')
    else:
        output.append('X')

# %%
len(output) == len(hb)
# Out:
# True

# %%
outputstr = ''.join(output)

# %% [markdown]
# This sequence now can be used to study the order of the characters

# %%
outputstr[:100]
# Out:
# 'CPCVCPVCVACXCVCVACXCVCACVCVCPAXCVACVCVXCPVCVACXCVCVCACVCXCPVCVCXXXCVCCVACXCVCPVACXCVCVCVCVACXCVCVACC'

# %%
hb[:100]
# Out:
# 'וּבִשְׁנַ֣ת אַחַ֗ת לְכ֨וֹרֶשׁ֙ מֶ֣לֶךְ פָּרַ֔ס לִכְל֥וֹת דְּבַר ־ יְהוָ֖ה מִפִּ֣י יִרְמְיָ֑ה הֵעִ֣יר'

# %% [markdown]
# Because the two sequences are of the same length we can zip them

# %%
list(zip(outputstr[:100], hb[:100]))
# Out:
# [('C', 'ו'),
#  ('P', 'ּ'),
#  ('C', 'ב'),
#  ('V', 'ִ'),
#  ('C', 'ש'),
#  ('P', 'ׁ'),
#  ('V', 'ְ'),
#  ('C', 'נ'),
#  ('V', 'ַ'),
#  ('A', '֣'),
#  ('C', 'ת'),
#  ('X', ' '),
#  ('C', 'א'),
#  ('V', 'ַ'),
#  ('C', 'ח'),
#  ('V', 'ַ'),
#  ('A', '֗'),
#  ('C', 'ת'),
#  ('X', ' '),
#  ('C', 'ל'),
#  ('V', 'ְ'),
#  ('C', 'כ'),
#  ('A', '֨'),
#  ('C', 'ו'),
#  ('V', 'ֹ'),
#  ('C', 'ר'),
#  ('V', 'ֶ'),
#  ('C', 'ש'),
#  ('P', 'ׁ'),
#  ('A', '֙'),
#  ('X', ' '),
#  ('C', 'מ'),
#  ('V', 'ֶ'),
#  ('A', '֣'),
#  ('C', 'ל'),
#  ('V', 'ֶ'),
#  ('C', 'ך'),
#  ('V', 'ְ'),
#  ('X', ' '),
#  ('C', 'פ'),
#  ('P', 'ּ'),
#  ('V', 'ָ'),
#  ('C', 'ר'),
#  ('V', 'ַ'),
#  ('A', '֔'),
#  ('C', 'ס'),
#  ('X', ' '),
#  ('C', 'ל'),
#  ('V', 'ִ'),
#  ('C', 'כ'),
#  ('V', 'ְ'),
#  ('C', 'ל'),
#  ('A', '֥'),
#  ('C', 'ו'),
#  ('V', 'ֹ'),
#  ('C', 'ת'),
#  ('X', ' '),
#  ('C', 'ד'),
#  ('P', 'ּ'),
#  ('V', 'ְ'),
#  ('C', 'ב'),
#  ('V', 'ַ'),
#  ('C', 'ר'),
#  ('X', ' '),
#  ('X', '־'),
#  ('X', ' '),
#  ('C', 'י'),
#  ('V', 'ְ'),
#  ('C', 'ה'),
#  ('C', 'ו'),
#  ('V', 'ָ'),
#  ('A', '֖'),
#  ('C', 'ה'),
#  ('X', ' '),
#  ('C', 'מ'),
#  ('V', 'ִ'),
#  ('C', 'פ'),
#  ('P', 'ּ'),
#  ('V', 'ִ'),
#  ('A', '֣'),
#  ('C', 'י'),
#  ('X', ' '),
#  ('C', 'י'),
#  ('V', 'ִ'),
#  ('C', 'ר'),
#  ('V', 'ְ'),
#  ('C', 'מ'),
#  ('V', 'ְ'),
#  ('C', 'י'),
#  ('V', 'ָ'),
#  ('A', '֑'),
#  ('C', 'ה'),
#  ('X', ' '),
#  ('C', 'ה'),
#  ('V', 'ֵ'),
#  ('C', 'ע'),
#  ('V', 'ִ'),
#  ('A', '֣'),
#  ('C', 'י'),
#  ('C', 'ר')]

# %% [markdown]
# We can count the number of cases where we have a vowel followed by a point. This is quite a lot

# %%
outputstr.count('VP')
# Out:
# 36009

# %% [markdown]
# Original:

# %%
# don't run
outputstr.count('VP')
# Out:
# 50278

# %% [markdown]
# # Analysis
#
# In what follows we will focus on sequence of two successive characters

# %%
bigrams = list(zip(output, output[1:]))
bigrams_hb = list(zip(hb, hb[1:]))

# %% [markdown]
# We'll create a new dataframe

# %%
b = pd.DataFrame([bigrams, bigrams_hb]).T

# %%
b.loc[b[0]==('V', 'P'), 1].value_counts()
# Out:
# (ָ, ֽ)    11294
# (ִ, ֽ)     7456
# (ֶ, ֽ)     4735
# (ֵ, ֽ)     4370
# (ַ, ֽ)     3947
# (ֹ, ֽ)     3364
# (ְ, ֽ)      614
# (ֻ, ֽ)      134
# (ֲ, ֽ)       53
# (ֱ, ֽ)       30
# (ֺ, ֽ)       12
# Name: 1, dtype: int64

# %%
hb[:100]
# Out:
# 'וּבִשְׁנַ֣ת אַחַ֗ת לְכ֨וֹרֶשׁ֙ מֶ֣לֶךְ פָּרַ֔ס לִכְל֥וֹת דְּבַר ־ יְהוָ֖ה מִפִּ֣י יִרְמְיָ֑ה הֵעִ֣יר'

# %%
def reverse(input):
    return ''.join(list(reversed(input)))

# %% [markdown]
# These are the cases where a point follows a vowel

# %% [markdown]
# AFTER the change:

# %%
print('{:>15} {:>15} {:>35} {:>35}'.format('Frequency', 'Raw data', 'Point', 'Vowel'))
for row in b.loc[b[0]==('V', 'P'), 1].value_counts().items():
    print('{:>15} {:>15} {:>35} {:>35}'.format(row[1], str(row[0]), unicodedata.name(row[0][1]), unicodedata.name(row[0][0])))
# Out:
#       Frequency        Raw data                               Point                               Vowel
#           11294      ('ָ', 'ֽ')                  HEBREW POINT METEG                 HEBREW POINT QAMATS
#            7456      ('ִ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT HIRIQ
#            4735      ('ֶ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT SEGOL
#            4370      ('ֵ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT TSERE
#            3947      ('ַ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT PATAH
#            3364      ('ֹ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT HOLAM
#             614      ('ְ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT SHEVA
#             134      ('ֻ', 'ֽ')                  HEBREW POINT METEG                 HEBREW POINT QUBUTS
#              53      ('ֲ', 'ֽ')                  HEBREW POINT METEG            HEBREW POINT HATAF PATAH
#              30      ('ֱ', 'ֽ')                  HEBREW POINT METEG            HEBREW POINT HATAF SEGOL
#              12      ('ֺ', 'ֽ')                  HEBREW POINT METEG    HEBREW POINT HOLAM HASER FOR VAV

# %%
# original
# do not run
print('{:>15} {:>15} {:>35} {:>35}'.format('Frequency', 'Raw data', 'Point', 'Vowel'))
for row in b.loc[b[0]==('V', 'P'), 1].value_counts().items():
    print('{:>15} {:>15} {:>35} {:>35}'.format(row[1], str(row[0]), unicodedata.name(row[0][1]), unicodedata.name(row[0][0])))
# Out:
#       Frequency        Raw data                               Point                               Vowel
#           11046      ('ָ', 'ֽ')                  HEBREW POINT METEG                 HEBREW POINT QAMATS
#            7177      ('ִ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT HIRIQ
#            4607      ('ֶ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT SEGOL
#            4306      ('ֵ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT TSERE
#            3888      ('ַ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT PATAH
#            3314      ('ֹ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT HOLAM
#            2901      ('ָ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                 HEBREW POINT QAMATS
#            2268      ('ִ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                  HEBREW POINT HIRIQ
#            2134      ('ְ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                  HEBREW POINT SHEVA
#            1482      ('ַ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                  HEBREW POINT PATAH
#             955      ('ֶ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                  HEBREW POINT SEGOL
#             951      ('ְ', 'ׁ')               HEBREW POINT SHIN DOT                  HEBREW POINT SHEVA
#             880      ('ֶ', 'ׁ')               HEBREW POINT SHIN DOT                  HEBREW POINT SEGOL
#             826      ('ֵ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                  HEBREW POINT TSERE
#             594      ('ְ', 'ֽ')                  HEBREW POINT METEG                  HEBREW POINT SHEVA
#             550      ('ֹ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                  HEBREW POINT HOLAM
#             513      ('ָ', 'ׁ')               HEBREW POINT SHIN DOT                 HEBREW POINT QAMATS
#             316      ('ְ', 'ׂ')                HEBREW POINT SIN DOT                  HEBREW POINT SHEVA
#             293      ('ִ', 'ׁ')               HEBREW POINT SHIN DOT                  HEBREW POINT HIRIQ
#             183      ('ָ', 'ׂ')                HEBREW POINT SIN DOT                 HEBREW POINT QAMATS
#             163      ('ַ', 'ׁ')               HEBREW POINT SHIN DOT                  HEBREW POINT PATAH
#             148      ('ֵ', 'ׁ')               HEBREW POINT SHIN DOT                  HEBREW POINT TSERE
#             134      ('ֻ', 'ֽ')                  HEBREW POINT METEG                 HEBREW POINT QUBUTS
#             114      ('ֹ', 'ׁ')               HEBREW POINT SHIN DOT                  HEBREW POINT HOLAM
#             112      ('ִ', 'ׂ')                HEBREW POINT SIN DOT                  HEBREW POINT HIRIQ
#              74      ('ֶ', 'ׂ')                HEBREW POINT SIN DOT                  HEBREW POINT SEGOL
#              66      ('ֻ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ                 HEBREW POINT QUBUTS
#              63      ('ֵ', 'ׂ')                HEBREW POINT SIN DOT                  HEBREW POINT TSERE
#              53      ('ֲ', 'ֽ')                  HEBREW POINT METEG            HEBREW POINT HATAF PATAH
#              46      ('ֻ', 'ׁ')               HEBREW POINT SHIN DOT                 HEBREW POINT QUBUTS
#              43      ('ַ', 'ׂ')                HEBREW POINT SIN DOT                  HEBREW POINT PATAH
#              30      ('ֱ', 'ֽ')                  HEBREW POINT METEG            HEBREW POINT HATAF SEGOL
#              27      ('ֹ', 'ׂ')                HEBREW POINT SIN DOT                  HEBREW POINT HOLAM
#              11      ('ֺ', 'ֽ')                  HEBREW POINT METEG    HEBREW POINT HOLAM HASER FOR VAV
#               3      ('ֺ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ    HEBREW POINT HOLAM HASER FOR VAV
#               3      ('ֻ', 'ׂ')                HEBREW POINT SIN DOT                 HEBREW POINT QUBUTS
#               2      ('ֲ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ            HEBREW POINT HATAF PATAH
#               1      ('ֲ', 'ׁ')               HEBREW POINT SHIN DOT            HEBREW POINT HATAF PATAH
#               1      ('ֳ', 'ּ')        HEBREW POINT DAGESH OR MAPIQ           HEBREW POINT HATAF QAMATS

# %% [markdown]
# Are there any VOWEL to VOWEL combinations?

# %%
print('{:>15} {:>15} {:>35} {:>35}'.format('Frequency', 'Raw data', 'Vowel', 'Vowel'))
for row in b.loc[b[0]==('V', 'V'), 1].value_counts().items():
    print('{:>15} {:>15} {:>35} {:>35}'.format(row[1], str(row[0]), unicodedata.name(row[0][1]), unicodedata.name(row[0][0])))
# Out:
#       Frequency        Raw data                               Vowel                               Vowel
#             208      ('ַ', 'ִ')                  HEBREW POINT HIRIQ                  HEBREW POINT PATAH
#             142      ('ָ', 'ִ')                  HEBREW POINT HIRIQ                 HEBREW POINT QAMATS
#              24      ('ִ', 'ַ')                  HEBREW POINT PATAH                  HEBREW POINT HIRIQ
#              18      ('ִ', 'ָ')                 HEBREW POINT QAMATS                  HEBREW POINT HIRIQ
#               2      ('ַ', 'ְ')                  HEBREW POINT SHEVA                  HEBREW POINT PATAH
#               1      ('ְ', 'ִ')                  HEBREW POINT HIRIQ                  HEBREW POINT SHEVA
#               1      ('ֹ', 'ָ')                 HEBREW POINT QAMATS                  HEBREW POINT HOLAM
#               1      ('ָ', 'ֹ')                  HEBREW POINT HOLAM                 HEBREW POINT QAMATS
#               1      ('ֹ', 'ְ')                  HEBREW POINT SHEVA                  HEBREW POINT HOLAM

# %%
cases = b.loc[b[0]==('V', 'V'), 1].value_counts().index.tolist()
cases
# Out:
# [('ַ', 'ִ'),
#  ('ָ', 'ִ'),
#  ('ִ', 'ַ'),
#  ('ִ', 'ָ'),
#  ('ַ', 'ְ'),
#  ('ְ', 'ִ'),
#  ('ֹ', 'ָ'),
#  ('ָ', 'ֹ'),
#  ('ֹ', 'ְ')]

# %%
for case in cases:
    print(case)
    print(unicodedata.name(case[0]))
    print(unicodedata.name(case[1]))
    print(re.findall(r'..........{}...........'.format(reverse(''.join(case))), hb))
    print()
# Out:
# ('ַ', 'ִ')
# HEBREW POINT PATAH
# HEBREW POINT HIRIQ
